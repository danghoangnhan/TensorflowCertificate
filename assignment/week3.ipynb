# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from package_from_scratch.regression import LinearRegression

# %%
data = pd.read_csv('../data/data_house.csv').values
data
# Out:
# array([[  30.    ,  448.524 ],
#        [  32.4138,  509.248 ],
#        [  34.8276,  535.104 ],
#        [  37.2414,  551.432 ],
#        [  39.6552,  623.418 ],
#        [  42.069 ,  625.992 ],
#        [  44.4828,  655.248 ],
#        [  46.8966,  701.377 ],
#        [  49.3103,  748.918 ],
#        [  51.7241,  757.881 ],
#        [  54.1379,  831.004 ],
#        [  56.5517,  855.409 ],
#        [  58.9655,  866.707 ],
#        [  61.3793,  902.545 ],
#        [  63.7931,  952.261 ],
#        [  66.2069,  995.531 ],
#        [  68.6207, 1069.78  ],
#        [  71.0345, 1074.42  ],
#        [  73.4483, 1103.88  ],
#        [  75.8621, 1138.69  ],
#        [  78.2759, 1153.13  ],
#        [  80.6897, 1240.27  ],
#        [  83.1034, 1251.9   ],
#        [  85.5172, 1287.97  ],
#        [  87.931 , 1320.47  ],
#        [  90.3448, 1374.92  ],
#        [  92.7586, 1410.16  ],
#        [  95.1724, 1469.69  ],
#        [  97.5862, 1478.54  ],
#        [ 100.    , 1515.28  ]])

# %%
x = data[:, 0].reshape(-1, 1)
y = data[:, 1].reshape(-1, 1)
model = LinearRegression(lr=0.000001, n_iters=100000)
model.fit(x,y)

# %%
plt.scatter(x,y)
plt.xlabel('acreage')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
# N = x.shape[0]
# x = np.hstack((np.ones((N, 1)), x))
# predict = model.predict(x)
# plt.plot((x[0][1], x[N-1][1]),(predict[0], predict[N-1]), 'r')
# plt.show()
# predict

# %%
plt.style.use('seaborn-whitegrid')
plt.rcParams['figure.dpi'] = 227
plt.rcParams['figure.figsize'] = (16, 5)
plt.plot(model.loss)
plt.title('Linear Regression Training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()
# Out:
# /tmp/ipykernel_187920/3683871412.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
