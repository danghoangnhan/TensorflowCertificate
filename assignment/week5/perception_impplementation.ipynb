# %%
import numpy as np
from package_from_scratch.Perceptron.Perceptron import Perceptron

# %%
# construct the XOR dataset
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

# define our perceptron and train it
print("[INFO] training perceptron...")
Perceptron_XOR = Perceptron(X.shape[1], eta=0.1)
Perceptron_XOR.fit(X, y, epochs=5000)
# now that our perceptron is trained we can evaluate it
print("[INFO] testing perceptron...")

# now that our network is trained, loop over the data points
for (x, target) in zip(X, y):
    # make a prediction on the data point and display the result
    # to our console
    pred = Perceptron_XOR.predict(x)
    print("[INFO] data={}, ground-truth={}, pred={}".format(x, target[0], pred))
# Out:
# [INFO] training perceptron...
# w1*x1+w2*x2+b:  0.2071826292883459
# w1*x1+w2*x2+b:  -0.3248659221942589
# w1*x1+w2*x2+b:  -0.316648826277998
# w1*x1+w2*x2+b:  -0.4486973777606028
# w1*x1+w2*x2+b:  0.30718262928834594
# w1*x1+w2*x2+b:  -0.12486592219425888
# w1*x1+w2*x2+b:  -0.116648826277998
# w1*x1+w2*x2+b:  -0.14869737776060288
# w1*x1+w2*x2+b:  0.4071826292883459
# w1*x1+w2*x2+b:  0.07513407780574113
# w1*x1+w2*x2+b:  -0.01664882627799802
# w1*x1+w2*x2+b:  -0.048697377760602845
# w1*x1+w2*x2+b:  0.4071826292883459
# w1*x1+w2*x2+b:  0.07513407780574113
# w1*x1+w2*x2+b:  0.08335117372200199
# w1*x1+w2*x2+b:  -0.14869737776060282
# w1*x1+w2*x2+b:  0.30718262928834594
# w1*x1+w2*x2+b:  -0.02486592219425887
# w1*x1+w2*x2+b:  0.08335117372200199
# w1*x1+w2*x2+b:  -0.04869737776060279
# w1*x1+w2*x2+b:  0.30718262928834594
# w1*x1+w2*x2+b:  0.07513407780574113
# w1*x1+w2*x2+b:  -0.01664882627799802
# w1*x1+w2*x2+b:  0.05130262223939719
# w1*x1+w2*x2+b:  0.20718262928834594
# ...

# %%
# construct the OR dataset
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [1]])

# define our perceptron and train it
print("[INFO] training perceptron...")
Perceptron_OR = Perceptron(X.shape[1], eta=0.1)
Perceptron_OR.fit(X, y, epochs=1000)
# now that our perceptron is trained we can evaluate it
print("[INFO] testing perceptron...")

# now that our network is trained, loop over the data points
for (x, target) in zip(X, y):
    # make a prediction on the data point and display the result
    # to our console
    pred = Perceptron_OR.predict(x)
    print("[INFO] data={}, ground-truth={}, pred={}".format(x, target[0], pred))
# Out:
# [INFO] training perceptron...
# w1*x1+w2*x2+b:  0.32778392965602016
# w1*x1+w2*x2+b:  0.35227152465673306
# w1*x1+w2*x2+b:  -0.054259178973873584
# w1*x1+w2*x2+b:  0.27022841602683934
# w1*x1+w2*x2+b:  0.32778392965602016
# w1*x1+w2*x2+b:  0.35227152465673306
# w1*x1+w2*x2+b:  0.04574082102612642
# w1*x1+w2*x2+b:  0.17022841602683936
# w1*x1+w2*x2+b:  0.22778392965602015
# w1*x1+w2*x2+b:  0.2522715246567331
# w1*x1+w2*x2+b:  -0.054259178973873584
# w1*x1+w2*x2+b:  0.27022841602683934
# w1*x1+w2*x2+b:  0.22778392965602015
# w1*x1+w2*x2+b:  0.2522715246567331
# w1*x1+w2*x2+b:  0.04574082102612642
# w1*x1+w2*x2+b:  0.17022841602683936
# w1*x1+w2*x2+b:  0.12778392965602015
# w1*x1+w2*x2+b:  0.15227152465673308
# w1*x1+w2*x2+b:  -0.054259178973873584
# w1*x1+w2*x2+b:  0.27022841602683934
# w1*x1+w2*x2+b:  0.12778392965602015
# w1*x1+w2*x2+b:  0.15227152465673308
# w1*x1+w2*x2+b:  0.04574082102612642
# w1*x1+w2*x2+b:  0.17022841602683936
# w1*x1+w2*x2+b:  0.02778392965602014
# ...

# %%
# construct the AND dataset
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [0], [0], [1]])

# define our perceptron and train it
print("[INFO] training perceptron...")
Perceptron_AND = Perceptron(X.shape[1], eta=0.1)
Perceptron_AND.fit(X, y, epochs=1000)
# now that our perceptron is trained we can evaluate it
print("[INFO] testing perceptron...")

# now that our network is trained, loop over the data points
for (x, target) in zip(X, y):
    # make a prediction on the data point and display the result
    # to our console
    pred = Perceptron_AND.predict(x)
    print("[INFO] data={}, ground-truth={}, pred={}".format(x, target[0], pred))
# Out:
# [INFO] training perceptron...
# w1*x1+w2*x2+b:  -0.3340662994645383
# w1*x1+w2*x2+b:  -0.21623584465976128
# w1*x1+w2*x2+b:  -1.0140272731437896
# w1*x1+w2*x2+b:  -0.8961968183390125
# w1*x1+w2*x2+b:  -0.2340662994645383
# w1*x1+w2*x2+b:  -0.016235844659761273
# w1*x1+w2*x2+b:  -0.8140272731437896
# w1*x1+w2*x2+b:  -0.5961968183390126
# w1*x1+w2*x2+b:  -0.1340662994645383
# w1*x1+w2*x2+b:  0.1837641553402387
# w1*x1+w2*x2+b:  -0.7140272731437897
# w1*x1+w2*x2+b:  -0.49619681833901264
# w1*x1+w2*x2+b:  -0.1340662994645383
# w1*x1+w2*x2+b:  0.1837641553402387
# w1*x1+w2*x2+b:  -0.6140272731437897
# w1*x1+w2*x2+b:  -0.3961968183390127
# w1*x1+w2*x2+b:  -0.1340662994645383
# w1*x1+w2*x2+b:  0.1837641553402387
# w1*x1+w2*x2+b:  -0.5140272731437897
# w1*x1+w2*x2+b:  -0.29619681833901274
# w1*x1+w2*x2+b:  -0.1340662994645383
# w1*x1+w2*x2+b:  0.1837641553402387
# w1*x1+w2*x2+b:  -0.41402727314378973
# w1*x1+w2*x2+b:  -0.19619681833901273
# w1*x1+w2*x2+b:  -0.1340662994645383
# ...
